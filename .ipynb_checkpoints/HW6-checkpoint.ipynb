# %% [markdown]
# # HW5 (Part 1) and HW6 (Part 2) - By: Divyesh Harit

# %% [markdown]
# # Vast Challenge - 2011, Mini Challenge 1 - Characterization of an Epidemic Spread
# <br>
# Goal - A major epidemic has started in the city of Vastopolis. The task is to analyze the data and determine how the epidemic is being spread and whether or not it is contained. The origin of the epidemic must also be identified.
# Dataset - Microblogging messages with geolocations and a map

# %% [markdown]
# ## Algorithms
#
# Get word counts, TF-IDF features for tweets - Will help in clustering alogrithms and also in visualization
# <br>
# **Clustering** - <br>
#     **Based on Location** - To see location where people are more active or totally inactive (if active then we can see what kind of message were coming in, whether epidemic is being spread or is contained, how are people reacting)
# <br>
#     **Based on Date/Time** - Will give a sense or a trend of how messages were changing with time (it could be either change in count or change in the context)<br>
#     **Based on Messages** - Will help in grouping messages<br><br>
# These 3 clustering results should give a good picture of the epidemic spread. We should be able to answer questions like how it started, how it is spreading, all affected aread and whether it is contained or not. <br>
# <br>
# **Classification** -<br>
#     Messages - Classifying messages into related to epidemic/disease and non-related will help in visualizing the results better. Infact, we can even run the clustering algorithms on the messages related to disease/epidemic.

# %% [markdown]
# ## Similar Dataset
# We decided to go with US twitter dataset present here - http://www.followthehashtag.com/datasets/free-twitter-dataset-usa-200000-free-usa-tweets/
# It has 200k tweets with geolocations, date and time. We selected this set as it was a close match with our mini challenge dataset.

# %% [markdown]
# # Classification
# We didn't run any classification algorithm on this. Instead,we looked at the dataset and decided to select rows where tweet had the word "#earthquake" and decided to do clustering on that to get a pattern.

# %%
import pandas as pd
import numpy as np
import csv
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from pandas import ExcelWriter
from pandas import ExcelFile
from sklearn import cluster
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
import bokeh
from bokeh.charts import Scatter
from bokeh.io import output_notebook,output_file
from bokeh.layouts import layout
from bokeh.models import Label
from bokeh.plotting import figure, show
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.simplefilter("ignore", UserWarning)
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="52a7b4ff-2998-47ae-b5e8-0ce6a36d9e99">Loading BokehJS ...</span>
#     </div>

# %%
# read data and select #earthquake related tweets
df = pd.read_excel('tweets1.xlsx')
df = df[['Tweet content','Latitude','Longitude', 'Date', 'Hour']]
data = df.loc[df['Tweet content'].str.contains("#earthquake")]

# %%
## word count, tf-idf features
###it is included in clustering by tweet content, there we first get word, count and tf-idf features

# %% [markdown]
# # Clustering

# %% [markdown]
# ## By Location

# %%
##Clustering by location
k_means = cluster.KMeans(6)
latlong = data.as_matrix(columns=['Latitude', 'Longitude'])
k_means.fit(latlong)
data['cluster'] = k_means.labels_
#plot = figure(width=550, height=550, title='K-means, 8 clusters', x_axis_label = "Grocery", y_axis_label = "Delicassen")
#plot.scatter(latlong[])
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
colors = np.array([x for x in ('#00f', '#0f0', '#f00', '#0ff', '#f0f', '#ff0')])
plot = figure(width=550, height=550, title='Clustering Tweets by Location', x_axis_label = "Latitude", y_axis_label = "Longitude")
plot.scatter(latlong[:,0],latlong[:,1], color = colors[k_means.labels_].tolist())
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b1e10525-7df0-4bf2-8516-4023c64afac2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("b1e10525-7df0-4bf2-8516-4023c64afac2");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b1e10525-7df0-4bf2-8516-4023c64afac2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b1e10525-7df0-4bf2-8516-4023c64afac2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0504646a-be6c-4a62-bbb3-c6ebcac4e5ce":{"roots":{"references":[{"attributes":{"axis_label":"Latitude","formatter":{"id":"6d386932-6c88-40e5-b133-063e6d916d08","type":"BasicTickFormatter"},"plot":{"id":"bce2ee17-eff6-4b12-be06-64916833b404","subtype":"Figure","type":"Plot"},"ticker":{"id":"a66c2cbd-f2cb-4f84-81aa-1e3b5d7e7e83","type":"BasicTicker"}},"id":"12791324-3ab6-46d6-8933-2fb853139dbe","type":"LinearAxis"},{"attributes":{"source":{"id":"6526db46-e7d3-4277-a35a-9b2993bd1e27","type":"ColumnDataSource"}},"id":"5774b7d9-aca9-4934-93e5-5db2a46ecde8","type":"CDSView"},{"attributes":{},"id":"7a667852-71de-4e25-8238-5891b69447c1","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"bce2ee17-eff6-4b12-be06-64916833b404","subtype":"Figure","type":"Plot"},"ticker":{"id":"a66c2cbd-f2cb-4f84-81aa-1e3b5d7e7e83","type":"BasicTicker"}},"id":"2c1529f3-d50d-49c9-835e-d9859610bc0e","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"bce2ee17-eff6-4b12-be06-64916833b404","subtype":"Figure","type":"Plot"},"ticker":{"id":"2703615d-2a3c-49e0-ba18-fbff6b3a7745","type":"BasicTicker"}},"id":"7351e99a-b5af-4e29-9bc2-890b95be36ba","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y","line_color","fill_color"],"data":{"fill_color":["#0f0","#0f0","#0ff","#0ff","#0ff","#0ff","#0f0","#0f0","#0ff","#0ff","#ff0","#ff0","#ff0","#ff0","#0ff","#0ff","#f00","#0ff","#0ff","#ff0","#ff0","#0f0","#0f0","#0f0","#0f0","#0ff","#0ff","#0f0","#0f0","#0f0","#0f0","#0f0","#0f0","#ff0","#f0f","#0ff","#0ff","#0ff","#0ff","#0ff","#f0f","#0ff","#0ff","#f0f","#f0f","#0ff","#0ff","#f0f","#0ff","#0ff","#0f0","#0f0","#ff0","#ff0","#0ff","#0ff","#00f","#00f","#0f0","#0f0","#0ff","#0ff","#0ff","#0ff","#0ff","#0ff","#0f0","#0f0","#0f0","#0f0","#0f0","#0f0","#0f0","#0f0","#0f0","#0ff","#0ff","#0ff","#0ff","#0ff","#0ff","#ff0","#ff0","#ff0","#0f0","#0f0","#0f0","#0f0","#00f","#00f","#00f","#00f","#0ff","#0ff","#0f0","#0f0","#0f0","#0f0","#ff0","#0ff","#0ff","#ff0","#ff0","#ff0","#0ff","#0ff","#0ff","#0f0","#0f0","#f0f","#0ff","#ff0","#ff0","#ff0","#0f0","#0f0","#ff0","#ff0","#ff0","#0f0","#0f0","#0f0","#0f0","#0f0","#0f0"],"line_color":["#0f0","#0f0","#0ff","#0ff","#0ff","#0ff","#0f0","#0f0","#0ff","#0ff","#ff0","#ff0","#ff0","#ff0","#0ff","#0ff","#f00","#0ff","#0ff","#ff0","#ff0","#0f0","#0f0","#0f0","#0f0","#0ff","#0ff","#0f0","#0f0","#0f0","#0f0","#0f0","#0f0","#ff0","#f0f","#0ff","#0ff","#0ff","#0ff","#0ff","#f0f","#0ff","#0ff","#f0f","#f0f","#0ff","#0ff","#f0f","#0ff","#0ff","#0f0","#0f0","#ff0","#ff0","#0ff","#0ff","#00f","#00f","#0f0","#0f0","#0ff","#0ff","#0ff","#0ff","#0ff","#0ff","#0f0","#0f0","#0f0","#0f0","#0f0","#0f0","#0f0","#0f0","#0f0","#0ff","#0ff","#0ff","#0ff","#0ff","#0ff","#ff0","#ff0","#ff0","#0f0","#0f0","#0f0","#0f0","#00f","#00f","#00f","#00f","#0ff","#0ff","#0f0","#0f0","#0f0","#0f0","#ff0","#0ff","#0ff","#ff0","#ff0","#ff0","#0ff","#0ff","#0ff","#0f0","#0f0","#f0f","#0ff","#ff0","#ff0","#ff0","#0f0","#0f0","#ff0","#ff0","#ff0","#0f0","#0f0","#0f0","#0f0","#0f0","#0f0"],"x":{"__ndarray__":"...","dtype":"float64","shape":[125]},"y":{"__ndarray__":"...","dtype":"float64","shape":[125]}}},"id":"6526db46-e7d3-4277-a35a-9b2993bd1e27","type":"ColumnDataSource"},{"attributes":{},"id":"6d386932-6c88-40e5-b133-063e6d916d08","type":"BasicTickFormatter"},{"attributes":{},"id":"97b84bff-b9f6-4c2c-b574-0eb68b76b421","type":"PanTool"},{"attributes":{},"id":"74d913ee-b621-4490-b8a2-131bfa45e600","type":"LinearScale"},{"attributes":{"plot":null,"text":"Clustering Tweets by Location"},"id":"5808ca9d-cae1-4040-9742-30092f8e8d74","type":"Title"},{"attributes":{"overlay":{"id":"1ccb0a03-dd82-4cf7-b931-7eb1daece177","type":"BoxAnnotation"}},"id":"dfead862-dfa3-4a39-a4ba-50bea68d58b1","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5b7d02ba-19b9-4628-95db-e7b7e4bcf2e8","ty ...

# %% [markdown]
# # By Tweets
# <br>
# We clustered tweets by bag of words and used PCA to transform the data and visualize it in 2d.

# %%
##Clustering by bag of words
pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
])        
X = pipeline.fit_transform(data["Tweet content"].tolist()).todense()
pca = PCA(n_components=2).fit(X)
data2D = pca.transform(X)

# %%
kmeans = cluster.KMeans(6)
kmeans.fit(X)
plot = figure(width=550, height=550, title='Clustering By Tweets')
plot.scatter(data2D[:,0], data2D[:,1],color=colors[k_means.labels_].tolist())
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="81e8afb5-6c14-4be6-963a-107c0cd5d84f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("81e8afb5-6c14-4be6-963a-107c0cd5d84f");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("81e8afb5-6c14-4be6-963a-107c0cd5d84f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '81e8afb5-6c14-4be6-963a-107c0cd5d84f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5d235dde-1f1f-438d-b0c5-bfe1d10f7415":{"roots":{"references":[{"attributes":{},"id":"acd7bc05-fb12-4f50-9f18-bc1dd23a5e57","type":"ResetTool"},{"attributes":{"callback":null},"id":"869d307a-23eb-48a0-9b5e-cb37c7e11ccd","type":"DataRange1d"},{"attributes":{},"id":"56e71b2d-870a-474d-9c32-d46fa685ee04","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b84e20cc-e1de-479a-a6a2-c31b43984ac2","type":"PanTool"},{"id":"441c79b6-9418-400d-81cb-c2d716eedad9","type":"WheelZoomTool"},{"id":"89b90e40-5f1e-4ff2-997c-5307067e0cc4","type":"BoxZoomTool"},{"id":"81d8e3fe-232c-4b16-9302-1336fad4b9ff","type":"SaveTool"},{"id":"acd7bc05-fb12-4f50-9f18-bc1dd23a5e57","type":"ResetTool"},{"id":"f4cbba58-0fa1-4f85-8ed2-12ae6deaf523","type":"HelpTool"}]},"id":"80e91dd5-ffa9-46e8-a17e-ceae2f883e8e","type":"Toolbar"},{"attributes":{"fill_color":{"field":"fill_color"},"line_color":{"field":"line_color"},"x":{"field":"x"},"y":{"field":"y"}},"id":"76763da8-0ca5-432c-aab9-ee8623805bf0","type":"Circle"},{"attributes":{"below":[{"id":"c0b63440-923d-49a0-87fc-0ae9e5bb8c8a","type":"LinearAxis"}],"left":[{"id":"3eeac8b5-3d28-4fee-a16f-ee8db0060588","type":"LinearAxis"}],"plot_height":550,"plot_width":550,"renderers":[{"id":"c0b63440-923d-49a0-87fc-0ae9e5bb8c8a","type":"LinearAxis"},{"id":"e6b96342-13ee-429f-86c9-5ddec603837d","type":"Grid"},{"id":"3eeac8b5-3d28-4fee-a16f-ee8db0060588","type":"LinearAxis"},{"id":"a1472bc1-4745-4d0e-a4cd-b5e737ff244b","type":"Grid"},{"id":"f79aeec4-c21f-4d58-a2f1-60881596a1e1","type":"BoxAnnotation"},{"id":"e9ea8bf4-2358-48e0-a15b-0f8f5b13ca58","type":"GlyphRenderer"}],"title":{"id":"6b157912-8dd3-41ee-9d8b-3ba4f6f105a7","type":"Title"},"toolbar":{"id":"80e91dd5-ffa9-46e8-a17e-ceae2f883e8e","type":"Toolbar"},"x_range":{"id":"869d307a-23eb-48a0-9b5e-cb37c7e11ccd","type":"DataRange1d"},"x_scale":{"id":"8c4e6735-63d8-4716-9411-ea178a1cdb6b","type":"LinearScale"},"y_range":{"id":"d33a6bae-a38d-4a53-8281-f084dfc153c5","type":"DataRange1d"},"y_scale":{"id":"561b8b97-0911-4053-b9c5-b684128160ad","type":"LinearScale"}},"id":"9ae89e58-6a3b-4674-b584-59919d2306e9","subtype":"Figure","type":"Plot"},{"attributes":{"overlay":{"id":"f79aeec4-c21f-4d58-a2f1-60881596a1e1","type":"BoxAnnotation"}},"id":"89b90e40-5f1e-4ff2-997c-5307067e0cc4","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":"Clustering By Tweets"},"id":"6b157912-8dd3-41ee-9d8b-3ba4f6f105a7","type":"Title"},{"attributes":{},"id":"81d8e3fe-232c-4b16-9302-1336fad4b9ff","type":"SaveTool"},{"attributes":{"callback":null},"id":"d33a6bae-a38d-4a53-8281-f084dfc153c5","type":"DataRange1d"},{"attributes":{"data_source":{"id":"d50d8d91-76b8-48ae-8f59-dd7e3ef1fb1d","type":"ColumnDataSource"},"glyph":{"id":"76763da8-0ca5-432c-aab9-ee8623805bf0","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"201da9a9-ecff-4789-b707-bd815a040907","type":"Circle"},"selection_glyph":null,"view":{"id":"dd456530-6c5b-4e2a-b8f9-c75031e2c879","type":"CDSView"}},"id":"e9ea8bf4-2358-48e0-a15b-0f8f5b13ca58","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"201da9a9-ecff-4789-b707-bd815a040907","type":"Circle"},{"attributes":{},"id":"0abfc351-d998-4b2d-84c5-713c2588a7e9","type":"BasicTicker"},{"attributes":{"formatter":{"id":"5909e001-6418-4b6b-aaf9-6ca23d30ad36","type":"BasicTickFormatter"},"plot":{"id":"9ae89e58-6a3b-4674-b584-59919d2306e9","subtype":"Figure","type":"Plot"},"ticker":{"id":"56e71b2d-870a-474d-9c32-d46fa685ee04","type":"BasicTicker"}},"id":"c0b63440-923d-49a0-87fc-0ae9e5bb8c8a","type":"LinearAxis"},{"attributes":{},"id":"5909e001-6418-4b6b-aaf9-6ca23d30ad36","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"a518a9af-7406-49cb-a2f0-bc5aa3fc1d2d","type":"BasicTickFormatter"},"plot":{"id" ...

# %% [markdown]
# # By Date/Time
# <br> The similar dataset didnt have tweets from very different times so we can just group the tweets by time and date.

# %%
data["Date"] = data["Date"].astype("datetime64")
# %matplotlib inline
data.groupby(data["Date"].dt.day).count().plot(kind="bar")
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %% [markdown]
# # Algorithms on Mini Challenge
# <br> We will have to implement a classification algo or use word-count/tf-idf features (output these out from clustering by tweets code) to classify tweets into related and non-related. Clustering should work well. We might have to try different clustering algorithms and then select the best.

# %% [markdown]
# # Visualizations
#
# <br> Here, we will now further explore our dataset and already chosen algorithms using interactive visualizations.

# %% [markdown]
# # Interactive location clustering

# %%
#assign a color to each label
def get_colors(labels):
    colors=[]
    for i in labels:
        if i==0.0 or i==0:
            colors.append('red')
        if i==1.0 or i==1:
            colors.append('#CAB2D6')
        if i==2.0 or i==2:
            colors.append('blue')
        if i==3.0 or i==3:
            colors.append('green')
        if i==4.0 or i==4:
            colors.append('black')
        if i==5.0 or i==5:
            colors.append('brown')
        if i==6.0 or i==6:
            colors.append('gray')
        if i==7.0 or i==7:
            colors.append('navy')
        if i==8.0 or i==8:
            colors.append('orange')
        if i==9.0 or i==9:
            colors.append('olive')
    return colors

# %%
from bokeh.io import push_notebook, show
from bokeh.layouts import widgetbox, row, column, layout
from bokeh.models import CustomJS, Select, Slider
from bokeh.models import ColumnDataSource, HoverTool, Legend, BoxZoomTool, ResetTool, LassoSelectTool, WheelZoomTool, PanTool

#Cluster
def clustering(number_of_clusters):
    kmeans = cluster.KMeans(n_clusters=number_of_clusters)
    return kmeans

#Initial, default clustering
clf = clustering(6)
clf.fit(latlong)
labels = clf.labels_
colors = get_colors(labels)

#Initial, default plot
source = ColumnDataSource(data=dict(x=latlong[:,0], y=latlong[:,1], colors=colors))
plot = figure(width=550, height=450, title='Clustering By Tweets', x_axis_label = "Latitude", y_axis_label = "Longitude",
              tools = [PanTool(), BoxZoomTool(), ResetTool(), LassoSelectTool(), WheelZoomTool()])
plot.circle('x','y', fill_color='colors', line_color='colors', source=source)
# Out:
# GlyphRenderer(id='f0907542-77d2-466f-9b58-e219cb49c2fd', ...)

# %%
def update_clusters(value):
    clusters = value
    clf = clustering(clusters)
    clf.fit(latlong)
    labels = clf.labels_ 
    colors = get_colors(labels)
    source.data=dict(x=latlong[:,0], y=latlong[:,1], colors=colors)
    push_notebook(handle=bokeh_handle)

callback = CustomJS(code="""
if (IPython.notebook.kernel !== undefined) {
    var kernel = IPython.notebook.kernel;
    cmd = "update_clusters(" + cb_obj.value + ")";
    kernel.execute(cmd, {}, {});
}
""")
    
#Slider to change clusters
slider = Slider(title="Number of clusters", value=6, start=2, end=10, step=1, width=200,
                callback=callback)

bokeh_handle = show(column(slider, plot), notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3965e990-f8e7-4181-a6eb-b92f51d2e750"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("3965e990-f8e7-4181-a6eb-b92f51d2e750");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3965e990-f8e7-4181-a6eb-b92f51d2e750");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3965e990-f8e7-4181-a6eb-b92f51d2e750' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"21f171d0-c3cb-42fe-af65-46f673d4b00f":{"roots":{"references":[{"attributes":{"callback":null},"id":"11365ff2-e0ec-41df-af5d-54c7078b683b","type":"DataRange1d"},{"attributes":{"children":[{"id":"344f24a1-8a32-4c71-9353-d63417f22b5b","type":"WidgetBox"},{"id":"58a6a2f0-35aa-4b42-8f76-d787471b57ea","subtype":"Figure","type":"Plot"}]},"id":"2ee1baf6-4c79-471b-b649-8a65fadafe4a","type":"Column"},{"attributes":{"source":{"id":"669a9248-4a3e-410c-9ff9-91c2f24bf28a","type":"ColumnDataSource"}},"id":"5d7b3291-e2e7-424a-9fed-31497620f2d9","type":"CDSView"},{"attributes":{},"id":"9d95c428-ee1d-413e-9af0-a89d6fe2c400","type":"LinearScale"},{"attributes":{"callback":null,"overlay":{"id":"2d80159a-a3f9-4bc9-8e01-68d0cffafbc5","type":"PolyAnnotation"}},"id":"ca5b3304-9dce-41f1-bdf3-9be548fdd7b0","type":"LassoSelectTool"},{"attributes":{},"id":"6dfa553d-3ef5-4a13-94bc-33386290e6e1","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"e2987775-272a-4177-9f93-c0cb928eac7e","type":"BoxAnnotation"}},"id":"296ac6ff-1077-42cb-bb3b-7d6bd7ffbb17","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"e6f2bdf4-9136-4338-bd8f-aa3cef87585c","type":"LinearAxis"}],"left":[{"id":"c68c9f5a-cb2a-495c-938f-ec3c09aa02c1","type":"LinearAxis"}],"plot_height":450,"plot_width":550,"renderers":[{"id":"e6f2bdf4-9136-4338-bd8f-aa3cef87585c","type":"LinearAxis"},{"id":"d52c39e2-8fb8-4de6-8b1d-72c0469c2bd5","type":"Grid"},{"id":"c68c9f5a-cb2a-495c-938f-ec3c09aa02c1","type":"LinearAxis"},{"id":"a1ea7191-0f16-4cd9-aebc-32f4705fffef","type":"Grid"},{"id":"e2987775-272a-4177-9f93-c0cb928eac7e","type":"BoxAnnotation"},{"id":"2d80159a-a3f9-4bc9-8e01-68d0cffafbc5","type":"PolyAnnotation"},{"id":"f0907542-77d2-466f-9b58-e219cb49c2fd","type":"GlyphRenderer"}],"title":{"id":"3e6d7447-d64a-40b8-8b8c-904b5d21747a","type":"Title"},"toolbar":{"id":"49407159-4d0c-41e9-a7e3-f325e92910d2","type":"Toolbar"},"x_range":{"id":"11365ff2-e0ec-41df-af5d-54c7078b683b","type":"DataRange1d"},"x_scale":{"id":"9d95c428-ee1d-413e-9af0-a89d6fe2c400","type":"LinearScale"},"y_range":{"id":"d3cdcfc6-52ed-4a2b-951a-792199cec3af","type":"DataRange1d"},"y_scale":{"id":"50d6e1e8-2d9c-41ae-b3c1-ceb230c478cd","type":"LinearScale"}},"id":"58a6a2f0-35aa-4b42-8f76-d787471b57ea","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"50d6e1e8-2d9c-41ae-b3c1-ceb230c478cd","type":"LinearScale"},{"attributes":{"callback":null,"column_names":["y","x","colors"],"data":{"colors":["red","red","#CAB2D6","#CAB2D6","#CAB2D6","#CAB2D6","red","red","#CAB2D6","#CAB2D6","black","black","black","black","#CAB2D6","#CAB2D6","blue","#CAB2D6","#CAB2D6","#CAB2D6","#CAB2D6","red","red","red","red","#CAB2D6","#CAB2D6","red","red","red","red","red","red","black","green","#CAB2D6","#CAB2D6","#CAB2D6","#CAB2D6","#CAB2D6","green","#CAB2D6","#CAB2D6","green","green","#CAB2D6","#CAB2D6","green","#CAB2D6","#CAB2D6","red","red","#CAB2D6","#CAB2D6","#CAB2D6","#CAB2D6","black","black","red","red","#CAB2D6","#CAB2D6","#CAB2D6","#CAB2D6","#CAB2D6","#CAB2D6","red","red","red","red","red","red","red","red","red","#CAB2D6","#CAB2D6","#CAB2D6","#CAB2D6","#CAB2D6","#CAB2D6","black","black","black","red","red","red","red","black","black","black","black","#CAB2D6","#CAB2D6","red","red","red","red","black","#CAB2D6","#CAB2D6","black","black","black","#CAB2D6","#CAB2D6","#CAB2D6","red","red","brown","#CAB2D6","black","black","black","red","red","#CAB2D6","black","black","red","red","red","red","red","red"],"x":{"__ndarray__":"...","dtype":"float64","shape":[125]},"y":{"__ndarray__":"...","dtype":"float64","shape":[125]}}},"id":"669a9248-4a3e-410c-9ff9-91c2f24bf28a","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e2987775-272 ...

# %% [markdown]
# The above interactive graph allows us to create clusters of different sizes according to their location, i.e, latitude and longitude. This allows us to group tweets according to the different locations that they originated from.
# We can apply something similar to the VAST Challenge, by first filtering tweets based on Epidemic or Disease related tweets, then clustering them by location, then finally digging deeper into the individual regions.

# %% [markdown]
# # Interactive Tweet Clustering

# %%
x = data2D[:,0]
y = data2D[:,1]

s1 = ColumnDataSource(data=dict(x=x, y=y))
p1 = figure(plot_width=400, plot_height=400, tools="lasso_select", title="Tweets: Select Here")
p1.scatter('x', 'y', source=s1, alpha=0.6, color=get_colors(k_means.labels_))

s2 = ColumnDataSource(data=dict(x=[], y=[]))
p2 = figure(plot_width=400, plot_height=400, x_range=(-0.3, 0.62), y_range=(-0.28, 0.45),
            tools="", title="Tweets: Watch Here")
p2.scatter('x', 'y', source=s2, alpha=0.6, color=get_colors(k_means.labels_))

s1.callback = CustomJS(args=dict(s2=s2), code="""
        var inds = cb_obj.selected['1d'].indices;
        var d1 = cb_obj.data;
        var d2 = s2.data;
        d2['x'] = []
        d2['y'] = []
        for (i = 0; i < inds.length; i++) {
            d2['x'].push(d1['x'][inds[i]])
            d2['y'].push(d1['y'][inds[i]])
        }
        s2.change.emit();
    """)

layout = row(p1, p2)

show(layout)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="decb7219-68ee-4ab4-b8e8-0447440fc6bc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("decb7219-68ee-4ab4-b8e8-0447440fc6bc");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("decb7219-68ee-4ab4-b8e8-0447440fc6bc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'decb7219-68ee-4ab4-b8e8-0447440fc6bc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8bff9316-a3f9-4ee0-8f74-8ffd6b68aab3":{"roots":{"references":[{"attributes":{"children":[{"id":"4919aa19-d1e7-4df0-b684-b7b769b740dd","subtype":"Figure","type":"Plot"},{"id":"560a73fb-40af-413a-8420-b3d4de0e4e79","subtype":"Figure","type":"Plot"}]},"id":"0bde8585-2600-4fab-b8f7-a14d2e30c63c","type":"Row"},{"attributes":{},"id":"49df856d-7b96-48a1-9339-f539378fefa8","type":"LinearScale"},{"attributes":{"callback":null},"id":"7d8a787e-dcff-455f-8e89-3dddc46e0a1a","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"field":"fill_color"},"line_alpha":{"value":0.6},"line_color":{"field":"line_color"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d66a30f1-fc1d-4c8f-b5f8-2157b5200300","type":"Circle"},{"attributes":{"args":{"s2":{"id":"0b798e22-d70f-492d-be40-ae80bfb1c779","type":"ColumnDataSource"}},"code":"\n        var inds = cb_obj.selected['1d'].indices;\n        var d1 = cb_obj.data;\n        var d2 = s2.data;\n        d2['x'] = []\n        d2['y'] = []\n        for (i = 0; i < inds.length; i++) {\n            d2['x'].push(d1['x'][inds[i]])\n            d2['y'].push(d1['y'][inds[i]])\n        }\n        s2.change.emit();\n    "},"id":"63153aad-8f90-4c9c-a62b-139a9b37447d","type":"CustomJS"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"field":"fill_color"},"line_alpha":{"value":0.6},"line_color":{"field":"line_color"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c6838103-7029-49cf-8f69-8ee24f88e4f6","type":"Circle"},{"attributes":{"formatter":{"id":"2eb0ce9a-1b53-46c4-8814-c893bbd40037","type":"BasicTickFormatter"},"plot":{"id":"4919aa19-d1e7-4df0-b684-b7b769b740dd","subtype":"Figure","type":"Plot"},"ticker":{"id":"36024f1d-2cd6-4cd5-bbb6-ef1253a9299d","type":"BasicTicker"}},"id":"5f3c5df2-51a4-401a-9a15-40247cd8e43f","type":"LinearAxis"},{"attributes":{},"id":"eb71f94a-3f95-4c21-a087-5dadeaea1867","type":"BasicTicker"},{"attributes":{},"id":"4ac84928-81b9-4cde-9864-e0c7701e9b1f","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"22d5c124-0334-47d7-b75f-a9a791744f7e","type":"LassoSelectTool"}]},"id":"0331bf47-6e29-439d-b238-1e098dea0e6d","type":"Toolbar"},{"attributes":{"plot":{"id":"560a73fb-40af-413a-8420-b3d4de0e4e79","subtype":"Figure","type":"Plot"},"ticker":{"id":"03c01f34-fbba-4ddf-acdf-bc05cd9d8f77","type":"BasicTicker"}},"id":"be017f99-ff46-460d-ad0c-598dbc423aa2","type":"Grid"},{"attributes":{"callback":null,"overlay":{"id":"89513bf0-2999-4590-98d6-47233bfdc4a4","type":"PolyAnnotation"}},"id":"22d5c124-0334-47d7-b75f-a9a791744f7e","type":"LassoSelectTool"},{"attributes":{"source":{"id":"0b798e22-d70f-492d-be40-ae80bfb1c779","type":"ColumnDataSource"}},"id":"350afa64-aebd-40ac-b5db-17d6add5e73b","type":"CDSView"},{"attributes":{},"id":"6e5a60b2-e52d-4deb-8145-1587888fcaaa","type":"LinearScale"},{"attributes":{},"id":"97a43133-519c-4939-b720-38ed36d47de8","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"e77354c8-5fde-4d09-89f1-807f6c4a4c8f","type":"LinearAxis"}],"left":[{"id":"5ff9a867-2713-4c88-bcba-40d00ad8e69d","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"e77354c8-5fde-4d09-89f1-807f6c4a4c8f","type":"LinearAxis"},{"id":"be017f99-ff46-460d-ad0c-598dbc423aa2","type":"Grid"},{"id":"5ff9a867-2713-4c88-bcba-40d00ad8e69d","type":"LinearAxis"},{"id":"6cffd9b1-7a02-4a43-81dd-ab93414b9b87","type":"Grid"},{"id":"928f46e0-3c46-4e36-b088-b440aeb8d5cb","type":"GlyphRenderer"}],"title":{"id":"8082c222-325a-460b-b174-67f08bc3007e","type":"Title"},"toolbar":{"id":"a80e5c1c-d7be-4e5c-9e82-ff9797be4044","type":"Toolbar"},"x_range":{"id":"82d58a0e-093e-4343-972c-a9823daf3f6d","type":"Range1d"},"x_scale":{"id":"98d04234-9158-4db8-b152-3faf3babf44d","type":"LinearScale"},"y_range":{"id":"5d8db4d5-ca26-42b7-8dc1-a5dccc76235c","type":"Range1d"},"y_scale":{"id":"6e5a60b2-e52d-4deb-8145-1587888fcaaa","type":"LinearScale"}},"id":"560a73fb-40af- ...

# %% [markdown]
# Here, we have filtered tweets on "#earthquake" basis, clustered using bag of words and then represented them in 2D after doing PCA dimensionality reduction. I'm honestly not sure if the results here helped again any more insights. The number of tweets are reduced to something far less than what's needed to gain any insights from, even with an interactive lasso select to highlight the selection.
# So we'd probably not use this approach for the VAST challenge. Maybe not filtering the tweets by any hashtags - simply doing PCA on the entire tweets column, plotting in 2D and doing the lasso select might help us gain some more information on the VAST challenge dataset.
